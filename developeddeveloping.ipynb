# %% [markdown]
# <a href="https://colab.research.google.com/github/qt19623/qt19623.github.io/blob/main/developeddeveloping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('classic')
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd

# %%
import json

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
path='/content/drive/My Drive/Colab Notebooks/food ghg emission world'

# %%
os.chdir(path)

# %%
stocks=pd.read_csv('developingdeveloped.csv')
stocks.head(2)
# Out:
#                 Country     Commodity Variable  TIME      Value
# 0  DEVELOPING COUNTRIES  Poultry meat     Food  1990  12123.999
# 1  DEVELOPING COUNTRIES  Poultry meat     Food  1991  17368.965

# %%
country = stocks['Country'].values
commodity= stocks['Commodity'].values
year=stocks['TIME'].values
value=stocks['Value'].values
variable=stocks['Variable'].values

# %%
countries=['Australia','Canada','Chile','Colombia','United Kingdom','Israel','Japan','Korea','Mexico','Norway','New Zealand','Switzerland','United States','Russian Federation','Egypt','Ethiopia','Nigeria','Argentina','Brazil','Paraguay','Peru','China','India','Indonesia','Iran','Kazakhstan']

# %%
df = pd.DataFrame({"country":country, "year":year, "foodvalue":value,"meat":commodity})
df = df[df.country == 'DEVELOPING COUNTRIES']
df = df[df['meat'].isin(['Beef and veal','Poultry meat','Sheepmeat','Pigmeat'])]

# %%
df1 = pd.DataFrame({"country":country, "year":year, "foodvalue":value,"meat":commodity})
df1 = df1[df1.country == 'DEVELOPED COUNTRIES']
df1 = df1[df1['meat'].isin(['Beef and veal','Poultry meat','Sheepmeat','Pigmeat'])]

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
fig.suptitle('Developed Developing')

sns.scatterplot( x =df.meat, y =df.year, size=df.foodvalue, legend=False, sizes=(20, 400),ax=axes[0])

sns.scatterplot( x =df1.meat, y =df1.year, size=df1.foodvalue, legend=False, sizes=(20, 800),ax=axes[1])

# %%
df2 = pd.DataFrame({"country":country, "year":year, "foodvalue":value,"meat":commodity})
df2 = df2[df2.meat == 'Beef and veal']
df2 = df2[df2['country'].isin(['DEVELOPED COUNTRIES','DEVELOPING COUNTRIES'])]

# %%
df3 = pd.DataFrame({"country":country, "year":year, "foodvalue":value,"meat":commodity})
df3 = df3[df3.meat == 'Poultry meat']
df3 = df3[df3['country'].isin(['DEVELOPED COUNTRIES','DEVELOPING COUNTRIES'])]

# %%
df4 = pd.DataFrame({"country":country, "year":year, "foodvalue":value,"meat":commodity})
df4 = df4[df4.meat == 'Pigmeat']
df4 = df4[df4['country'].isin(['DEVELOPED COUNTRIES','DEVELOPING COUNTRIES'])]

# %%
df5 = pd.DataFrame({"country":country, "year":year, "foodvalue":value,"meat":commodity})
df5 = df5[df5.meat == 'Sheepmeat']
df5 = df5[df5['country'].isin(['DEVELOPED COUNTRIES','DEVELOPING COUNTRIES'])]

# %%
fig, axes1 = plt.subplots(1, 4, figsize=(5, 5), sharey=True)
fig.suptitle('Developed Developing meat')
sns.scatterplot( x =df3.country, y =df3.year, size=df3.foodvalue, legend=False, sizes=(20, 400),ax=axes1[0])

sns.scatterplot( x =df4.country, y =df4.year, size=df4.foodvalue, legend=False, sizes=(20, 400),ax=axes1[1])
sns.scatterplot( x =df5.country, y =df5.year, size=df5.foodvalue, legend=False, sizes=(20, 400),ax=axes1[2])

sns.scatterplot( x =df2.country, y =df2.year, size=df2.foodvalue, legend=False, sizes=(20, 400),ax=axes1[3])
